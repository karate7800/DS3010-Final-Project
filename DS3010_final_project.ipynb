# %%
from sklearn.tree import DecisionTreeClassifier
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline


# reading the data 
df = pd.read_csv('ds3010projdataset.csv')

df1 = df.drop(['International', 'Nationality'], axis = 1)
df1.head()

df2 = df1.drop(['Application order', 'Application mode', 'Marital status'], axis = 1)
df2.head()
# Out:
#    Course  Daytime/evening attendance  Previous qualification  \
# 0       2                           1                       1
# 1      11                           1                       1
# 2       5                           1                       1
# 3      15                           1                       1
# 4       3                           0                       1
#
#    Mother's qualification  Father's qualification  Mother's occupation  \
# 0                      13                      10                    6
# 1                       1                       3                    4
# 2                      22                      27                   10
# 3                      23                      27                    6
# 4                      22                      28                   10
#
#    Father's occupation  Displaced  Educational special needs  Debtor  ...  \
# 0                   10          1                          0       0  ...
# 1                    4          1                          0       0  ...
# 2                   10          1                          0       0  ...
# 3                    4          1                          0       0  ...
# 4                   10          0                          0       0  ...
#
#    Curricular units (credited)  Curricular units (enrolled)  \
# 0                            0                            0
# 1                            0                           12
# 2                            0                           12
# 3                            0                           12
# 4                            0                           12
#
#    Curricular units (evaluations)  Curricular units (approved)  \
# 0                               0                            0
# 1                              12                           12
# 2                               0                            0
# 3                              18                           11
# 4                              15                           11
#
#    Curricular units (grade)  Curricular units (without evaluations)  \
# 0                  0.000000                                       0
# 1                 27.666667                                       0
# 2                  0.000000                                       0
# 3                 25.828571                                       0
# 4                 25.333333                                       0
#
#    Unemployment rate  Inflation rate   GDP    Target
# 0               10.8             1.4  1.74   Dropout
# 1               13.9            -0.3  0.79  Graduate
# 2               10.8             1.4  1.74   Dropout
# 3                9.4            -0.8 -3.12  Graduate
# 4               13.9            -0.3  0.79  Graduate
#
# [5 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split
X = df2.drop('Target', axis = 1)
y = df2[['Target']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, train_size=0.70)

print(len(X_train))
print(len(X_test))

clfModel = DecisionTreeClassifier(criterion = 'gini', random_state =1, max_depth = 5, min_samples_leaf = 10)
clfModel.fit(X_train, y_train)
# Out:
# 3096
# 1328
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=10, random_state=1)

# %%
from sklearn.metrics import accuracy_score
yPredict = clfModel.predict(X_test)

accuracy_score(y_test, yPredict)
# Out:
# 0.7424698795180723

# %%
from sklearn import tree

target = list(df['Target'].unique())
features = list(X.columns)

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clfModel, 
                   feature_names = features,  
                   class_names = target,
                   filled=True)

# %%
from sklearn.ensemble import RandomForestClassifier

rfcModel = RandomForestClassifier(random_state=1, n_estimators = 215)

rfcModel.fit(X_train, y_train)
y_pred = rfcModel.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# C:\Users\duong\AppData\Local\Temp\ipykernel_11944\2755343012.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfcModel.fit(X_train, y_train)
# 0.7793674698795181
